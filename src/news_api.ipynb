# %%
import requests

url = ('https://newsapi.org/v2/everything?'
       'q=Apple&AI'
       'from=2025-03-10&'
       'sortBy=popularity&'
       'apiKey=237d140128514a4bb46272ece0d0bbff')

response = requests.get(url)

# %%
print(response.json())
# Out:
# {'status': 'ok', 'totalResults': 40864, 'articles': [{'source': {'id': None, 'name': 'Yahoo Entertainment'}, 'author': 'Devindra Hardawar', 'title': 'A $599 iPhone 16e is a cruel joke', 'description': 'The $599 iPhone 16e is many things, but don\'t you dare call it a budget phone. I hesitate to even call it "cheap." As a successor to the $429 iPhone SE, it\'s hard not to see the 16e as a disappointment. Sure, it\'s $200 less than the vanilla iPhone 16 (which I…', 'url': 'https://consent.yahoo.com/v2/collectConsent?sessionId=1_cc-session_6a9d7824-1075-43db-9d49-fc79e61d0672', 'urlToImage': None, 'publishedAt': '2025-02-20T20:05:07Z', 'content': "If you click 'Accept all', we and our partners, including 238 who are part of the IAB Transparency &amp; Consent Framework, will also store and/or access information on a device (in other words, use … [+703 chars]"}, {'source': {'id': None, 'name': 'Yahoo Entertainment'}, 'author': 'Mariella Moon', 'title': 'Apple AirTag four-packs drop to a n
# ...
